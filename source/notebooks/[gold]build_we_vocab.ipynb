# %%
import logging
logging.basicConfig(level=logging.INFO)
from pathlib import Path

import numpy as np
import pandas as pd
from gensim.models import Word2Vec

from naruto_skills.new_voc import Voc
from naruto_skills.word_embedding import WordEmbedding
# Out:
# INFO:summarizer.preprocessing.cleaner:'pattern' package not found; tag filters are not available for English

# %% [markdown]
# # Wiki

# %%
root = '/dataset/'

# %%
class CsvSubdirsCorpus(object):
    """
    Iterable: on each iteration, return bag-of-words vectors,
    one vector for each document.
 
    Process one document at a time using generators, never
    load the entire corpus into RAM.
 
    """
    def __init__(self, top_dir):
        self.top_dir = top_dir
 
    def __iter__(self):
        """
        Again, __iter__ is a generator => TxtSubdirsCorpus is a streamed iterable.
        """
        for idx, p in enumerate(Path(self.top_dir).glob('wiki_clean.csv')):
            # read each document as one big string
            dfs = pd.read_csv(p, chunksize=5e5)
            for df in dfs:
                list_docs = list(df['target'].dropna())
                for doc in list_docs:
                    yield doc.lower().split()

# %%
corpus = CsvSubdirsCorpus(root)

# %%
model = Word2Vec(corpus, size=300, window=10, min_count=100, workers=8)

# %%
len(model.wv.index2word)

# %%
model.save('/source/main/vocab/output/word2vec_gensim_model_wiki')

# %%
model.wv.index2entity[-10:]

# %%
model.get_latest_training_loss()

# %%
model.most_similar('méo')
model.most_similar('gà')
model.most_similar('chó')
# model.most_similar('fuck')
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# INFO:gensim.models.keyedvectors:precomputing L2-norms of word weight vectors
# /opt/conda/lib/python3.6/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# [('mèo', 0.7636736631393433),
#  ('thỏ', 0.6197304725646973),
#  ('cún', 0.6055511236190796),
#  ('khỉ', 0.6011084914207458),
#  ('sói', 0.5494617223739624),
#  ('nhím', 0.5479783415794373),
#  ('husky', 0.5313003659248352),
#  ('cọp', 0.5297122001647949),
#  ('dê', 0.5252997875213623),
#  ('trâu', 0.5251345634460449)]

# %% [markdown]
# # Training wiki + social

# %%
social = '/source/main/preprocess/output/topics/'
wiki = '/dataset/'

class CsvSubdirsCorpus(object):
    """
    Iterable: on each iteration, return bag-of-words vectors,
    one vector for each document.
 
    Process one document at a time using generators, never
    load the entire corpus into RAM.
 
    """
    def __init__(self, wiki, social):
        self.wiki = wiki
        self.social = social
 
    def __iter__(self):
        """
        Again, __iter__ is a generator => TxtSubdirsCorpus is a streamed iterable.
        """
        for idx, p in enumerate(Path(self.wiki).glob('wiki_clean.csv')):
            # read each document as one big string
            dfs = pd.read_csv(p, chunksize=5e5)
            for df in dfs:
                list_docs = list(df['target'].dropna())
                for doc in list_docs:
                    yield doc.lower().split()
                    
        for idx, p in enumerate(Path(self.social).glob('*.csv')):
            # read each document as one big string
            dfs = pd.read_csv(p, chunksize=5e5)
            for df in dfs:
                list_docs = list(df['mention'].dropna())
                for doc in list_docs:
                    yield doc.lower().split()
        
corpus = CsvSubdirsCorpus(wiki, social)

# %%
model = Word2Vec(corpus, size=300, window=20, min_count=100, workers=8)
# Out:
# INFO:gensim.models.word2vec:collecting all words and their counts
# INFO:gensim.models.word2vec:PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #10000, processed 380505 words, keeping 10358 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #20000, processed 762565 words, keeping 15922 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #30000, processed 1144077 words, keeping 20856 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #40000, processed 1528381 words, keeping 25453 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #50000, processed 1911770 words, keeping 29782 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #60000, processed 2295922 words, keeping 33795 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #70000, processed 2677760 words, keeping 37662 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #80000, processed 3059976 words, keeping 41569 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #90000, processed 3444285 words, keeping 45096 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #100000, processed 3826103 words, keeping 48674 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #110000, processed 4207818 words, keeping 52328 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #120000, processed 4588699 words, keeping 55862 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #130000, processed
words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 56.70% examples, 1042054 words/s, in_qsize 16, out_qsize 1
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 56.88% examples, 1042596 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 57.06% examples, 1043017 words/s, in_qsize 15, out_qsize 1
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 57.12% examples, 1037122 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 57.29% examples, 1037407 words/s, in_qsize 8, out_qsize 5
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 57.48% examples, 1038069 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 57.65% examples, 1038554 words/s, in_qsize 12, out_qsize 3
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 57.83% examples, 1039023 words/s, in_qsize 16, out_qsize 3
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 58.02% examples, 1039558 words/s, in_qsize 15, out_qsize 2
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 58.20% examples, 1040109 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 58.37% examples, 1040521 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 58.55% examples, 1040966 words/s, in_qsize 12, out_qsize 3
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 58.74% examples, 1041537 words/s, in_qsize 14, out_qsize 2
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 58.91% examples, 1041967 words/s, in_qsize 15, out_qsize 3
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 59.10% examples, 1042464 words/s, in_qsize 16, out_qsize 4
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 59.28% examples, 1042995 words/s, in_qsize 15, out_qsize 2
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 59.46% examples, 1043477 words/s, in_qsize 16, out_qsize 2
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 59.50% examples, 1037648 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 59.68% examples, 1038151 words/s, in_qsize 14, out_qsize 1
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 59.86% examples, 1038662 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 60.04% examples, 1039096 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 60.22% examples, 1039663 words/s, in_qsize 14, out_qsize 2
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 60.40% examples, 1040148 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 60.58% examples, 1040571 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 60.76% examples, 1041116 words/s, in_qsize 13, out_qsize 2
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 60.94% examples, 1041578 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 61.11% examples, 1041873 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 61.28% examples, 1042270 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 61.47% examples, 1042796 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 61.64% examples, 1043115 words/s, in_qsize 16, out_qsize 5
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 61.81% examples, 1043569 words/s, in_qsize 16, out_qsize 2
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 61.88% examples, 1038201 words/s, in_qsize 3, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 62.05% examples, 1038537 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 62.23% examples, 1039008 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 62.40% examples, 1039414 words/s, in_qsize 16, out_qsize 1
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 62.58% examples, 1039854 words/s, in_qsize 16, out_qsize 2
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 62.76% examples, 1040271 words/s, in_qsize 14, out_qsize 1
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 62.93% examples, 1040677 words/s, in_qsize 16, out_qsize 1
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 63.11% examples, 1041145 words/s, in_qsize 16, out_qsize 1
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 63.29% examples, 1041522 words/s, in_qsize 12, out_qsize 3
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 63.46% examples, 1041780 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 63.63% examples, 1042187 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 63.81% examples, 1042613 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 63.99% examples, 1043061 words/s, in_qsize 14, out_qsize 1
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 64.17% examples, 1043460 words/s, in_qsize 14, out_qsize 1
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 64.26% examples, 1038189 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 64.43% examples, 1038552 words/s, in_qsize 15, out_qsize 2
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 64.61% examples, 1038932 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 64.79% examples, 1039422 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 64.96% examples, 1039803 words/s, in_qsize 12, out_qsize 3
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 65.14% examples, 1040240 words/s, in_qsize 15, out_qsize 1
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 65.33% examples, 1040760 words/s, in_qsize 15, out_qsize 1
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 65.52% examples, 1041360 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 65.70% examples, 1041811 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 65.87% examples, 1042142 words/s, in_qsize 14, out_qsize 4
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 66.05% examples, 1042560 words/s, in_qsize 12, out_qsize 3
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 66.23% examples, 1042996 words/s, in_qsize 16, out_qsize 1
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 66.40% examples, 1043341 words/s, in_qsize 14, out_qsize 1
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 66.57% examples, 1043507 words/s, in_qsize 16, out_qsize 2
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 66.64% examples, 1038430 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 66.82% examples, 1038927 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 67.00% examples, 1039321 words/s, in_qsize 14, out_qsize 3
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 67.18% examples, 1039683 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 67.35% examples, 1040091 words/s, in_qsize 16, out_qsize 2
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 67.54% examples, 1040570 words/s, in_qsize 13, out_qsize 2
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 67.72% examples, 1041085 words/s, in_qsize 13, out_qsize 2
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 67.89% examples, 1041396 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 68.08% examples, 1042012 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 68.26% examples, 1042351 words/s, in_qsize 12, out_qsize 4
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 68.43% examples, 1042598 words/s, in_qsize 14, out_qsize 5
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 68.60% examples, 1042934 words/s, in_qsize 15, out_qsize 7
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 68.78% examples, 1043413 words/s, in_qsize 15, out_qsize 1
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 68.96% examples, 1043767 words/s, in_qsize 12, out_qsize 3
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 69.02% examples, 1038705 words/s, in_qsize 16, out_qsize 1
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 69.20% examples, 1039194 words/s, in_qsize 14, out_qsize 1
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 69.38% examples, 1039649 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 69.57% examples, 1040125 words/s, in_qsize 14, out_qsize 1
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 69.74% examples, 1040521 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 69.92% examples, 1040891 words/s, in_qsize 15, out_qsize 2
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 70.09% examples, 1041208 words/s, in_qsize 16, out_qsize 1
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 70.26% examples, 1041456 words/s, in_qsize 14, out_qsize 5
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 70.45% examples, 1041958 words/s, in_qsize 15, out_qsize 0

# %%
model.save('/source/main/vocab/output/word2vec_gensim_model_wiki_social')

# %%
model.

# %%
model.most_similar('sống')
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('sống…', 0.5705943703651428),
#  ('đời', 0.49514040350914),
#  ('sống..', 0.45615914463996887),
#  ('sống-', 0.43332797288894653),
#  ('sống.-', 0.3902968168258667),
#  ('sống.', 0.3377140760421753),
#  ('đời…', 0.32389163970947266),
#  ('rốt', 0.3238018751144409),
#  ('sống', 0.3073164224624634),
#  ('mít-tinh', 0.3070906102657318)]

# %%
len(model.wv.index2word)
# Out:
# 26636

# %%
voc = Voc(tokenize_func=Voc.WORD_LV_TOK_FUNC, space_char=Voc.WORD_LV_SPACE_CHR)

# %%
voc.add_embedding_weights()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-672b7048b6f0> in <module>
# ----> 1 voc.add_embedding_weights()
#
# NameError: name 'voc' is not defined

# %% [markdown]
# # Create Voc

# %%
model = Word2Vec.load('/source/main/vocab/output/word2vec_gensim_model_wiki_social')
# Out:
# INFO:gensim.utils:loading Word2Vec object from /source/main/vocab/output/word2vec_gensim_model_wiki_social
# WARNING:smart_open.smart_open_lib:this function is deprecated, use smart_open.open instead
# INFO:gensim.utils:loading wv recursively from /source/main/vocab/output/word2vec_gensim_model_wiki_social.wv.* with mmap=None
# INFO:gensim.utils:setting ignored attribute vectors_norm to None
# INFO:gensim.utils:loading vocabulary recursively from /source/main/vocab/output/word2vec_gensim_model_wiki_social.vocabulary.* with mmap=None
# INFO:gensim.utils:loading trainables recursively from /source/main/vocab/output/word2vec_gensim_model_wiki_social.trainables.* with mmap=None
# INFO:gensim.utils:setting ignored attribute cum_table to None
# INFO:gensim.utils:loaded /source/main/vocab/output/word2vec_gensim_model_wiki_social

# %%
print(model.wv.syn0[0][:10])
print(model.wv.syn0[-1][:10])
# Out:
# [ 0.09677044 -0.5980865   1.6606522   0.3972973   0.00939904 -0.01667785
#  -1.4936599  -1.1991605  -0.29754373 -0.17177866]
# [ 0.0013401  -0.04555359  0.11077558 -0.02073835  0.08600322 -0.01954939
#  -0.02022713  0.00361845  0.1397001   0.04248903]

# %%
model.wv.add(['__p__', '__o__'], np.random.normal(loc=model.wv.syn0.mean(), scale=model.wv.syn0.std(),
                                             size=(2, model.wv.syn0.shape[1])))
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `syn0` (Attribute will be removed in 4.0.0, use self.wv.vectors instead).
#   """Entry point for launching an IPython kernel.
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated `syn0` (Attribute will be removed in 4.0.0, use self.wv.vectors instead).

# %%
vocabs = model.wv.index2word
weights = model.wv.syn0
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated `syn0` (Attribute will be removed in 4.0.0, use self.wv.vectors instead).

# %%
len(vocabs)
# Out:
# 26638

# %%
vocabs[-10:]
# Out:
# ['vuitetnhuy',
#  'rén..',
#  'chamnhethemyeulanda',
#  'fiala',
#  'antamhungthinhtoandien',
#  'bifidusbl',
#  'stra',
#  'lgsuperuhdtv',
#  '__p__',
#  '__o__']

# %%
voc = Voc(tokenize_func=Voc.WORD_LV_TOK_FUNC, space_char=Voc.WORD_LV_SPACE_CHR)

# %%
len(vocabs)
# Out:
# 26638

# %%
voc.build_from_tokens(vocabs, padding_idx=len(vocabs)-2, oov_idx=len(vocabs)-1)

# %%
voc.add_embedding_weights(model.wv.syn0)
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `syn0` (Attribute will be removed in 4.0.0, use self.wv.vectors instead).
#   """Entry point for launching an IPython kernel.

# %%
voc.freeze()

# %%
voc.dump('/source/main/vocab/output/voc.pkl')

# %% [markdown]
# # Check it

# %%
del voc

# %%
voc = Voc.load('/source/main/vocab/output/voc.pkl')

# %%
voc.docs2idx(['đá'])
# Out:
# [[624]]

# %%
model.wv.get_vector('đá')[:10]
# Out:
# array([ 0.75781786,  1.6542717 ,  0.163088  , -0.04168139,  4.2450223 ,
#         2.8398998 ,  2.542663  , -1.376479  ,  1.4295504 ,  1.575918  ],
#       dtype=float32)

# %%
voc.get_embedding_weights()[624][:10]
# Out:
# array([ 0.75781786,  1.65427172,  0.16308799, -0.04168139,  4.2450223 ,
#         2.83989978,  2.5426631 , -1.37647903,  1.42955041,  1.57591796])
